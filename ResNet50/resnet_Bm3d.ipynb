# %%
import os
import torch
import torch.nn as nn
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from torchvision.datasets.folder import default_loader
from torchvision import transforms
import numpy as np
import random
import matplotlib.pyplot as plt
from torchvision.utils import make_grid
import time
import copy
from tqdm import tqdm

# %%
batch_size = 128


train_dir = "/home/branislava.jankovic/Desktop/denoising-pneumonia/bm3d_dataset/train"
val_dir = "/home/branislava.jankovic/Desktop/denoising-pneumonia/bm3d_dataset/val"
test_dir = "/home/branislava.jankovic/Desktop/denoising-pneumonia/bm3d_dataset/test"

transform = transforms.Compose(
                [
                    transforms.Resize((224, 224)),
                    transforms.ToTensor(),
                ]
            )

train_data = ImageFolder(train_dir, transform=transform, loader=default_loader)
val_data = ImageFolder(val_dir, transform=transform, loader=default_loader)
test_data = ImageFolder(test_dir, transform=transform, loader=default_loader)

image_datasets = {'train': train_data, 'validation': val_data}

# %%
def START_seed():
    seed = 9
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

# %%
# load dataset
START_seed()
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True, num_workers = 8)
val_loader = DataLoader(dataset=val_data, batch_size=batch_size, shuffle=True, num_workers = 8)
test_loader = DataLoader(dataset=test_data, batch_size=batch_size, shuffle=False, num_workers = 8)

dataloaders = {
    'train': train_loader, 
    'validation':val_loader
}

# %%
for images, _ in train_loader:
    print('images.shape:', images.shape)
    plt.figure(figsize=(16,8))
    plt.axis('off')
    plt.imshow(make_grid(images, nrow=16).permute((1, 2, 0)))
    break
# Out:
# images.shape: torch.Size([128, 3, 224, 224])

# %%
from torchvision.models import resnet50, ResNet50_Weights


# weights_path = "/home/dawlat.akaila/Documents/AI_LABS/PROJECT_FINAL/denoising-pneumonia/pc-nih-rsna-siim-vin-resnet50-test512-e400-state.pt"

# Load the weights into the model
resnet50_model = resnet50(weights=None)

# checkpoint = torch.load(weights_path)
# resnet50_model.load_state_dict(checkpoint['train'])

# print(resnet50_model.fc.in_features)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu') 
model = resnet50_model.to(device=device) 

# for param in model.parameters():
#     param.requires_grad = False   
    
model.fc = nn.Sequential(
               nn.Linear(2048, 128),
               nn.BatchNorm1d(128),
               nn.Dropout(0.3),
               nn.ReLU(inplace=True),
               nn.Linear(128, 2)).to(device)

# Number of parameters
total_params = sum(p.numel() for p in model.parameters())
print(total_params)
# Out:
# 23770818

# %%
# Loss and optimizer
lr=1e-6
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr= lr)

# %%
def train_resnet(model, criterion, optimizer, num_epochs=3):
    best_model_wts = None
    best_acc = 0.0

    start_time = time.time()
    train_losses_per_epochs = []
    val_losses_per_epochs = []
    train_acc_per_epochs = []
    val_acc_per_epochs = []
    
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-' * 10)

        for phase in ['train', 'validation']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0

            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                outputs = model(inputs)
                loss = criterion(outputs, labels)

                if phase == 'train':
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()

                _, preds = torch.max(outputs, 1)
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(image_datasets[phase])
            epoch_acc = running_corrects.double() / len(image_datasets[phase])

            if phase == 'train':
                train_losses_per_epochs.append(epoch_loss)
                train_acc_per_epochs.append(epoch_acc.item())
            else:
                val_losses_per_epochs.append(epoch_loss)
                val_acc_per_epochs.append(epoch_acc.item())

            print('{} loss: {:.4f}, acc: {:.4f}'.format(phase,
                                                        epoch_loss,
                                                        epoch_acc))
            
            if phase == "validation" and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
                torch.save(best_model_wts, "resnet50_denoised.pth")

    print("Time:", (time.time() - start_time))
    return model, train_losses_per_epochs, val_losses_per_epochs, train_acc_per_epochs, val_acc_per_epochs

# %%
model_trained, train_losses_per_epochs, val_losses_per_epochs, train_acc_per_epochs, val_acc_per_epochs = train_resnet(model, criterion, optimizer, num_epochs=20)
# Out:
# Epoch 1/20
# ----------
# train loss: 0.5804, acc: 0.7182
# validation loss: 0.8485, acc: 0.5000
# Epoch 2/20
# ----------
# train loss: 0.5155, acc: 0.7780
# validation loss: 0.6806, acc: 0.6250
# Epoch 3/20
# ----------
# train loss: 0.4838, acc: 0.7977
# validation loss: 0.6929, acc: 0.6250
# Epoch 4/20
# ----------
# train loss: 0.4645, acc: 0.8090
# validation loss: 0.6878, acc: 0.7500
# Epoch 5/20
# ----------
# train loss: 0.4423, acc: 0.8238
# validation loss: 0.6900, acc: 0.7500
# Epoch 6/20
# ----------
# train loss: 0.4313, acc: 0.8271
# validation loss: 0.6647, acc: 0.6875
# Epoch 7/20
# ----------
# train loss: 0.4224, acc: 0.8317
# validation loss: 0.6208, acc: 0.7500
# Epoch 8/20
# ----------
# train loss: 0.4109, acc: 0.8390
# validation loss: 0.6172, acc: 0.7500
# Epoch 9/20
# ----------
# train loss: 0.4017, acc: 0.8484
# validation loss: 0.5970, acc: 0.7500
# Epoch 10/20
# ----------
# train loss: 0.3926, acc: 0.8522
# validation loss: 0.5911, acc: 0.6875
# Epoch 11/20
# ----------
# train loss: 0.3860, acc: 0.8589
# validation loss: 0.5834, acc: 0.6875
# Epoch 12/20
# ----------
# train loss: 0.3761, acc: 0.8572
# validation loss: 0.5776, acc: 0.6875
# Epoch 13/20
# ----------
# train loss: 0.3669, acc: 0.8683
# validation loss: 0.5621, acc: 0.6875
# Epoch 14/20
# ----------
# train loss: 0.3583, acc: 0.8727
# validation loss: 0.5632, acc: 0.6875
# Epoch 15/20
# ----------
# train loss: 0.3520, acc: 0.8765
# validation loss: 0.5978, acc: 0.6875
# Epoch 16/20
# ----------
# train loss: 0.3422, acc: 0.8831
# validation loss: 0.5963, acc: 0.6875
# Epoch 17/20
# ----------
# train loss: 0.3370, acc: 0.8846
# validation loss: 0.6249, acc: 0.6875
# Epoch 18/20
# ----------
# train loss: 0.3292, acc: 0.8900
# validation loss: 0.6506, acc: 0.6875
# Epoch 19/20
# ----------
# train loss: 0.3178, acc: 0.8972
# validation loss: 0.6098, acc: 0.6875
# Epoch 20/20
# ----------
# train loss: 0.3133, acc: 0.8997
# validation loss: 0.6034, acc: 0.6875
# Time: 587.7958872318268

# %%
fig, ax = plt.subplots(figsize=(12, 4))
fig.suptitle("Train and Validation Loss")
ax.plot(
    train_losses_per_epochs,
    alpha=0.2,
    label="Train Loss",
    color="black",
)
ax.plot(val_losses_per_epochs, label="Validation Loss")


# Set x-label and y-label
ax.set_xlabel("Epochs")
ax.set_ylabel("Loss")
fig.savefig("Train_and_Validation_Loss_ResNet")

_ = ax.legend()

# %%
fig, ax = plt.subplots(figsize=(12, 4))
fig.suptitle("Train and Validation Acc")
ax.plot(
    train_acc_per_epochs,
    alpha=0.2,
    label="Train Acc",
    color="black",
)
ax.plot(val_acc_per_epochs, label="Validation Acc")


# Set x-label and y-label
ax.set_xlabel("Epochs")
ax.set_ylabel("Acc")
fig.savefig("Train_and_Validation_Acc_ResNet")

_ = ax.legend()

# %%
def test_best_model(model, test_loader, criterion, best_model_path):
    # Load the best model
    model.load_state_dict(torch.load(best_model_path))
    model.eval()

    test_loss = 0
    correct = 0
    total = 0

    with tqdm(test_loader, unit="batch") as tepoch:
        for batch_idx, (data, target) in enumerate(tepoch):
            data, target = data.to(device), target.to(device)

            output = model(data)
            loss = criterion(output, target)
            test_loss += loss.item()

            _, predicted = output.max(1)
            total += target.size(0)
            correct += predicted.eq(target).sum().item()

        accuracy = 100. * correct / total
        print('Test loss: {:.4f} Accuracy: {:.2f}%'.format(test_loss/(batch_idx+1), accuracy))

# %%
# Usage example:

# Assuming you have a model, test_loader, and best_model_path defined

best_resnet_path = '/home/branislava.jankovic/Desktop/denoising-pneumonia/resnet50_denoised.pth'  # Replace with the actual path and filename of the best model

test_best_model(model=resnet50_model, test_loader=test_loader, criterion=criterion, best_model_path=best_resnet_path)
# Out:
# 100%|██████████| 5/5 [00:07<00:00,  1.41s/batch]
# Test loss: 0.5239 Accuracy: 76.60%
