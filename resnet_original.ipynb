# %%
import os
import torch
import torch.nn as nn
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from torchvision.datasets.folder import default_loader
from torchvision import transforms
import numpy as np
import random
import matplotlib.pyplot as plt
from torchvision.utils import make_grid
import time
import copy
from tqdm import tqdm

# %%
batch_size = 128


train_dir = "/home/branislava.jankovic/Desktop/denoising-pneumonia/chest_xray/train"
val_dir = "/home/branislava.jankovic/Desktop/denoising-pneumonia/chest_xray/val"
test_dir = "/home/branislava.jankovic/Desktop/denoising-pneumonia/chest_xray/test"

transform = transforms.Compose(
                [
                    transforms.Resize((224, 224)),
                    transforms.ToTensor(),
                ]
            )

train_data = ImageFolder(train_dir, transform=transform, loader=default_loader)
val_data = ImageFolder(val_dir, transform=transform, loader=default_loader)
test_data = ImageFolder(test_dir, transform=transform, loader=default_loader)

image_datasets = {'train': train_data, 'validation': val_data}

# %%
def START_seed():
    seed = 9
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

# %%
# load dataset
START_seed()
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True, num_workers = 8)
val_loader = DataLoader(dataset=val_data, batch_size=batch_size, shuffle=True, num_workers = 8)
test_loader = DataLoader(dataset=test_data, batch_size=batch_size, shuffle=False, num_workers = 8)

dataloaders = {
    'train': train_loader, 
    'validation':val_loader
}

# %%
for images, _ in train_loader:
    print('images.shape:', images.shape)
    plt.figure(figsize=(16,8))
    plt.axis('off')
    plt.imshow(make_grid(images, nrow=16).permute((1, 2, 0)))
    break
# Out:
# images.shape: torch.Size([128, 3, 224, 224])

# %%
from torchvision.models import resnet50


# weights_path = "/home/dawlat.akaila/Documents/AI_LABS/PROJECT_FINAL/denoising-pneumonia/pc-nih-rsna-siim-vin-resnet50-test512-e400-state.pt"

# Load the weights into the model
resnet50_model = resnet50(weights=None)

# checkpoint = torch.load(weights_path)
# resnet50_model.load_state_dict(checkpoint['train'])

# print(resnet50_model.fc.in_features)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu') 
model = resnet50_model.to(device=device) 

# for param in model.parameters():
#     param.requires_grad = False   
    
model.fc = nn.Sequential(
               nn.Linear(2048, 128),
               nn.BatchNorm1d(128),
               nn.Dropout(0.3),
               nn.ReLU(inplace=True),
               nn.Linear(128, 2)).to(device)

# Number of parameters
total_params = sum(p.numel() for p in model.parameters())
print(total_params)
# Out:
# 23770818

# %%
# Loss and optimizer
lr=1e-6
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr= lr)

# %%
def train_resnet(model, criterion, optimizer, num_epochs=3):
    best_model_wts = None
    best_acc = 0.0

    start_time = time.time()
    train_losses_per_epochs = []
    val_losses_per_epochs = []
    train_acc_per_epochs = []
    val_acc_per_epochs = []
    
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-' * 10)

        for phase in ['train', 'validation']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0

            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                outputs = model(inputs)
                loss = criterion(outputs, labels)

                if phase == 'train':
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()

                _, preds = torch.max(outputs, 1)
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(image_datasets[phase])
            epoch_acc = running_corrects.double() / len(image_datasets[phase])

            if phase == 'train':
                train_losses_per_epochs.append(epoch_loss)
                train_acc_per_epochs.append(epoch_acc.item())
            else:
                val_losses_per_epochs.append(epoch_loss)
                val_acc_per_epochs.append(epoch_acc.item())

            print('{} loss: {:.4f}, acc: {:.4f}'.format(phase,
                                                        epoch_loss,
                                                        epoch_acc))
            
            if phase == "validation" and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
                torch.save(best_model_wts, "resnet50.pth")

    print("Time:", (time.time() - start_time))
    return model, train_losses_per_epochs, val_losses_per_epochs, train_acc_per_epochs, val_acc_per_epochs

# %%
model_trained, train_losses_per_epochs, val_losses_per_epochs, train_acc_per_epochs, val_acc_per_epochs = train_resnet(model, criterion, optimizer, num_epochs=20)
# Out:
# Epoch 1/20
# ----------
# train loss: 0.5800, acc: 0.7268
# validation loss: 0.8641, acc: 0.5000
# Epoch 2/20
# ----------
# train loss: 0.5135, acc: 0.7841
# validation loss: 0.6755, acc: 0.6250
# Epoch 3/20
# ----------
# train loss: 0.4856, acc: 0.7974
# validation loss: 0.6370, acc: 0.6875
# Epoch 4/20
# ----------
# train loss: 0.4664, acc: 0.8083
# validation loss: 0.6175, acc: 0.7500
# Epoch 5/20
# ----------
# train loss: 0.4444, acc: 0.8219
# validation loss: 0.5908, acc: 0.7500
# Epoch 6/20
# ----------
# train loss: 0.4370, acc: 0.8263
# validation loss: 0.6152, acc: 0.6875
# Epoch 7/20
# ----------
# train loss: 0.4283, acc: 0.8292
# validation loss: 0.5927, acc: 0.6875
# Epoch 8/20
# ----------
# train loss: 0.4187, acc: 0.8378
# validation loss: 0.5954, acc: 0.7500
# Epoch 9/20
# ----------
# train loss: 0.4110, acc: 0.8461
# validation loss: 0.6111, acc: 0.6875
# Epoch 10/20
# ----------
# train loss: 0.3988, acc: 0.8434
# validation loss: 0.5955, acc: 0.7500
# Epoch 11/20
# ----------
# train loss: 0.3950, acc: 0.8562
# validation loss: 0.5507, acc: 0.7500
# Epoch 12/20
# ----------
# train loss: 0.3852, acc: 0.8568
# validation loss: 0.5629, acc: 0.7500
# Epoch 13/20
# ----------
# train loss: 0.3720, acc: 0.8712
# validation loss: 0.5865, acc: 0.6250
# Epoch 14/20
# ----------
# train loss: 0.3646, acc: 0.8687
# validation loss: 0.5920, acc: 0.6250
# Epoch 15/20
# ----------
# train loss: 0.3593, acc: 0.8731
# validation loss: 0.6389, acc: 0.6875
# Epoch 16/20
# ----------
# train loss: 0.3518, acc: 0.8765
# validation loss: 0.5758, acc: 0.6250
# Epoch 17/20
# ----------
# train loss: 0.3428, acc: 0.8798
# validation loss: 0.6246, acc: 0.6875
# Epoch 18/20
# ----------
# train loss: 0.3359, acc: 0.8903
# validation loss: 0.5785, acc: 0.6875
# Epoch 19/20
# ----------
# train loss: 0.3279, acc: 0.8861
# validation loss: 0.6618, acc: 0.6875
# Epoch 20/20
# ----------
# train loss: 0.3212, acc: 0.8961
# validation loss: 0.6307, acc: 0.6250
# Time: 510.4764811992645

# %%
fig, ax = plt.subplots(figsize=(12, 4))
fig.suptitle("Train and Validation Loss")
ax.plot(
    train_losses_per_epochs,
    alpha=0.2,
    label="Train Loss",
    color="black",
)
ax.plot(val_losses_per_epochs, label="Validation Loss")


# Set x-label and y-label
ax.set_xlabel("Epochs")
ax.set_ylabel("Loss")
fig.savefig("Train_and_Validation_Loss_ResNet")

_ = ax.legend()

# %%
fig, ax = plt.subplots(figsize=(12, 4))
fig.suptitle("Train and Validation Acc")
ax.plot(
    train_acc_per_epochs,
    alpha=0.2,
    label="Train Acc",
    color="black",
)
ax.plot(val_acc_per_epochs, label="Validation Acc")


# Set x-label and y-label
ax.set_xlabel("Epochs")
ax.set_ylabel("Acc")
fig.savefig("Train_and_Validation_Acc_ResNet")

_ = ax.legend()

# %%
def test_best_model(model, test_loader, criterion, best_model_path):
    # Load the best model
    model.load_state_dict(torch.load(best_model_path))
    model.eval()

    test_loss = 0
    correct = 0
    total = 0

    with tqdm(test_loader, unit="batch") as tepoch:
        for batch_idx, (data, target) in enumerate(tepoch):
            data, target = data.to(device), target.to(device)

            output = model(data)
            loss = criterion(output, target)
            test_loss += loss.item()

            _, predicted = output.max(1)
            total += target.size(0)
            correct += predicted.eq(target).sum().item()

        accuracy = 100. * correct / total
        print('Test loss: {:.4f} Accuracy: {:.2f}%'.format(test_loss/(batch_idx+1), accuracy))

# %%
# Usage example:

# Assuming you have a model, test_loader, and best_model_path defined

best_resnet_path = '/home/branislava.jankovic/Desktop/denoising-pneumonia/resnet50.pth'  # Replace with the actual path and filename of the best model

test_best_model(model=resnet50_model, test_loader=test_loader, criterion=criterion, best_model_path=best_resnet_path)
# Out:
#   0%|          | 0/5 [00:00<?, ?batch/s]
# 100%|██████████| 5/5 [00:04<00:00,  1.12batch/s]
# Test loss: 0.5475 Accuracy: 72.28%
